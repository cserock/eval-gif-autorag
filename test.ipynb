# %%
import pandas as pd

qa_parquet_path='./data/qa.parquet'
qa_data = pd.read_parquet(qa_parquet_path, engine='pyarrow')
qa_data.head(50)
# Out:
#              qid                                              query  \
# 0         80_law  원고 A이 시력 저하등의 증상이 발생한 시점은 언제로 보고, 그 시점 판단의 기준은...
# 1      4_finance  2024년도 한국은행의 대정부 일시대출금 한도와 대출조건을 결정하는 과정에서 보완된...
# 2      40_public  2023년에 발표된 '가을철 지역축제 안전관리협조 요청 사항'은 무엇인지, 그리고 ...
# 3         69_law  국세기본법 제14조 제2항에서 언급하는 과세표준의 계산에 관한 규정이 어떠한 실질내...
# 4     10_finance  비은행 금융기관의 부동산 PF 대출 연체율 상승에 따른 미래적 영향은 무엇이며, 어...
# 5      45_public  2023년 벤처투자 회복을 위해 변화된 '복수의결권' 시행과 전면 네거티브 규제특례...
# 6         70_law  관세법 시행령 제19조 제3항 제1호 다목, 제2호는 어떠한 상황에서 권리사용료가 ...
# 7         66_law  가상자산소득에 대한 개정 소득세법 제21조 제1항 제27호, 제119조 제12호 타...
# 8      47_public  정부의 소상공인 지원과 관련해 '대환대출', '일시적 경영 애로자금'의 확대 예산 ...
# 9     11_finance  미 연준은 어떠한 이유로 인해 금리인하를 결정하기에는 이른 시점이라고 평가하였나요?...
# 10   98_commerce  이커머스 소비자들이 가장 관심을 두는 정보와 그 다음으로 관심을 두는 정보는 무엇이...
# 11     36_public  2002년부터 2023년까지 학생 한 명당 장서(도서) 수가 어떻게 변화하였고, 이...
# 12        83_law    원고 주식회사가 제기한 특허무효심판 청구의 결과에 대해 어떤 절차와 결론이 있었나요?
# ...

# %%
import pandas as pd

corpus_parquet_path='./data/corpus.parquet'
corpus_data = pd.read_parquet(corpus_parquet_path, engine='pyarrow')
corpus_data.head(50)
# Out:
#                                                doc_id  \
# 0                               law - 형사_피고인이.pdf - 1
# 1                                law - 행정_원고가.pdf - 6
# 2                   commerce - 이커머스 솔루션 소개자료.pdf - 36
# 3                               law - 행정_타인자금.pdf - 5
# 4                                law - 행정_금품.pdf - 23
# 5                   commerce - 이커머스 솔루션 소개자료.pdf - 47
# 6                   commerce - 이커머스 솔루션 소개자료.pdf - 45
# 7   commerce - Dighty Data Insight Report 2023.pdf...
# 8                                law - 행정_원고가.pdf - 8
# 9                      law -  2024 달라지는 세금제도.pdf - 27
# 10             finance - 한-호주 퇴직연금 포럼_책자(최종).pdf - 36
# 11                               law - 행정_금품.pdf - 18
# 12                  commerce - 이커머스 솔루션 소개자료.pdf - 21
# 13         commerce - MezzoMedia 산업 보고서 e커머스.pdf - 32
# 14                             law - 민사_스마트폰.pdf - 35
# 15                              law - 행정_원고가.pdf - 44
# ...

# %%
import pandas as pd

qa_parquet_path='./data/qa.parquet'
qa_data = pd.read_parquet(qa_parquet_path, engine='pyarrow')
qa_data.head(50)
# Out:
#                                 retrieval_gt  \
# 0   [[8adaa96e-23e0-4e09-b0fc-2190962378d3]]
# 1   [[2d335cc9-5abd-4648-b695-af73e3862c55]]
# 2   [[df9ceb6d-864a-4c19-8534-414f2a055cce]]
# 3   [[652f5375-762d-4bd4-b877-b360fa743313]]
# 4   [[027a6b2d-9c2f-463c-85d9-20773197527d]]
# 5   [[79dd5496-7f3d-469a-b991-0ad43db03c2e]]
# 6   [[d6aad734-ce3f-41d4-95cc-ad051ab5bf3a]]
# 7   [[73d0ce1c-0f4c-4ab1-82d8-0a8e506c65ae]]
# 8   [[7e92601a-c632-487b-968b-0c4d98ea8802]]
# 9   [[b328f3a1-3d77-4412-b687-bf0fa1eb112b]]
# 10  [[05c5d540-5532-4cce-9c87-f58afa6d014f]]
# 11  [[4c2d4685-2b46-4891-8823-5313471b2a98]]
# 12  [[c6533a1a-f7d4-415d-959f-2803b959687d]]
# 13  [[4fec0242-b0e7-417c-9deb-f859a4296de3]]
# 14  [[e6fa287b-796a-4330-ad55-343eade22919]]
# 15  [[f81c73f1-6fea-4e81-8306-90848fcebe52]]
# 16  [[5e76113a-9802-48cf-968f-913aff9c8041]]
# 17  [[379b3125-aa7f-4dd8-b3ab-758ed2261290]]
# 18  [[2435e45f-83e6-40b0-9bb4-b24f6117cb61]]
# 19  [[3f535f4b-a510-471e-83fb-9e398ef44bdb]]
#
# ...

# %%
import pandas as pd

corpus_parquet_path='./data/corpus.parquet'
corpus_data = pd.read_parquet(corpus_parquet_path, engine='pyarrow')
corpus_data.head(50)
# Out:
#                                   doc_id  \
# 0   b328f3a1-3d77-4412-b687-bf0fa1eb112b
# 1   5e76113a-9802-48cf-968f-913aff9c8041
# 2   379b3125-aa7f-4dd8-b3ab-758ed2261290
# 3   3f535f4b-a510-471e-83fb-9e398ef44bdb
# 4   05c5d540-5532-4cce-9c87-f58afa6d014f
# 5   c6533a1a-f7d4-415d-959f-2803b959687d
# 6   ec2e8055-b764-47f1-bdea-a2872d3e1ec9
# 7   90dfb419-274f-4fcf-83f1-db8b93bd449a
# 8   027a6b2d-9c2f-463c-85d9-20773197527d
# 9   79dd5496-7f3d-469a-b991-0ad43db03c2e
# 10  4e0fa450-9ae9-4aa3-bfd4-945287fbbff1
# 11  e6fa287b-796a-4330-ad55-343eade22919
# 12  7e92601a-c632-487b-968b-0c4d98ea8802
# 13  4fec0242-b0e7-417c-9deb-f859a4296de3
# 14  8f923c86-de13-4ef9-8f12-0839f5c8d7fd
# 15  2d335cc9-5abd-4648-b695-af73e3862c55
# 16  4c2d4685-2b46-4891-8823-5313471b2a98
# 17  652f5375-762d-4bd4-b877-b360fa743313
# 18  7f48e16d-e386-497b-91e6-e0b16ade8731
# 19  d6aad734-ce3f-41d4-95cc-ad051ab5bf3a
# 20  c0cb3e06-1037-4f8e-a3ff-24dd867a8152
# 21  73d0ce1c-0f4c-4ab1-82d8-0a8e506c65ae
# ...
